# %%
# !pip install transformers
# !pip install wget

import tensorflow as tf
import transformers
from google.colab import files
import torch

import os

# %%
device_name = tf.test.gpu_device_name()

if torch.cuda.is_available():    
    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")
    print('There are %d GPU(s) available.' % torch.cuda.device_count())
    print('We will use the GPU:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# No GPU available, using the CPU instead.

# %%
from google.colab import drive

drive.mount('/content/gdrive')

os.chdir('/content/gdrive/My Drive/Colab Notebooks/')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
os.chdir('./biobert/')

# %%
bert_config_file = './biobert/biobert_model/biobert_v1.1_pubmed/bert_config.json'
tf_checkpoint_path = '/content/gdrive/My Drive/Colab Notebooks/biobert/biobert_model/biobert_v1.1_pubmed/model.ckpt-1000000'
pytorch_dump_path = './biobert/biobert_model/biobert_pytorch_model/'

# %%
# %run convert_bert_original_tf_checkpoint_to_pytorch.py \
  --tf_checkpoint_path='/content/gdrive/My Drive/Colab Notebooks/biobert/biobert_model/biobert_v1.1_pubmed/model.ckpt-1000000' \
  --bert_config_file='/content/gdrive/My Drive/Colab Notebooks/biobert/biobert_model/biobert_v1.1_pubmed/bert_config.json' \
  --pytorch_dump_path='/content/gdrive/My Drive/Colab Notebooks/biobert/biobert_model/biobert_v1.1_pubmed/biobert_pytorch_model/biobert_v1.1_pytorch'
# Out:
# Building PyTorch model from configuration: {
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 28996
# }
#
# Save PyTorch model to /content/gdrive/My Drive/Colab Notebooks/biobert/biobert_model/biobert_v1.1_pubmed/biobert_pytorch_model/biobert_v1.1_pytorch

# %%
torch.load('/content/gdrive/My Drive/Colab Notebooks/biobert/biobert_model/biobert_v1.1_pubmed/biobert_pytorch_model/biobert_v1.1_pytorch')
# Out:
# OrderedDict([('bert.embeddings.word_embeddings.weight',
#               tensor([[-0.0265, -0.0074, -0.0290,  ..., -0.0363, -0.0341,  0.0183],
#                       [-0.0116,  0.0133, -0.0578,  ..., -0.0236, -0.0681, -0.0066],
#                       [ 0.0233,  0.0052, -0.0251,  ..., -0.0698, -0.0221, -0.0255],
#                       ...,
#                       [-0.0297, -0.0520, -0.0594,  ..., -0.0552, -0.0592,  0.0144],
#                       [-0.0454,  0.0151, -0.0613,  ..., -0.0792, -0.0300, -0.0051],
#                       [ 0.0303, -0.0056, -0.0408,  ..., -0.0215, -0.0521, -0.0016]])),
#              ('bert.embeddings.position_embeddings.weight',
#               tensor([[ 0.0337,  0.0085,  0.0037,  ...,  0.0033,  0.0170,  0.0158],
#                       [-0.0255, -0.0157, -0.0083,  ...,  0.0023,  0.0099,  0.0098],
#                       [-0.0003,  0.0047,  0.0072,  ...,  0.0075,  0.0042, -0.0051],
#                       ...,
# ...
